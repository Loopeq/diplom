# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 962.0 kB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 11.2 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 17.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.4 pandas-3.0.3

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from statsmodels) (2.4.4)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from statsmodels) (3.0.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from statsmodels) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 14.4 MB/s eta 0:00:0000:010:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 15.4 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 16.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-1.0.2 scipy-1.17.1 statsmodels-0.14.6

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /home/senya/.cache/pypoetry/virtualenvs/diplom-4lLjUWpD-py3.12/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 6.3 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 16.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0

# %%
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error


warnings.filterwarnings("ignore")


# =========================
# 1. Пути
# =========================

csv_path = Path.cwd() / "dataset" / "demand_primary_training_minimal.csv"

out_forecast = Path.cwd() / "dataset" / "sarimax_forecast_2025_fixed.csv"
out_metrics = Path.cwd() / "dataset" / "sarimax_metrics_2025_fixed.csv"


# =========================
# 2. Загрузка
# =========================

df = pd.read_csv(csv_path)

df["period_end"] = pd.to_datetime(df["period_end"])
df["period"] = df["period_end"].dt.to_period("Q")

df = df.sort_values(["product_name", "period"])

target_col = "target_demand_index"


# =========================
# 3. Настройки
# =========================

train_end = pd.Period("2024Q4", freq="Q")
forecast_end = pd.Period("2025Q4", freq="Q")

order = (1, 1, 1)
seasonal_order = (1, 0, 1, 4)

min_observations = 12

partial_products = [
    "Бензины автомобильные",
    "Газовое моторное топливо",
    "Дизельное топливо",
]


# =========================
# 4. Метрики
# =========================

def rmse(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    return np.sqrt(np.mean((y_true - y_pred) ** 2))


def mape(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)

    mask = y_true != 0

    if mask.sum() == 0:
        return np.nan

    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100


def wape(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)

    denominator = np.sum(np.abs(y_true))

    if denominator == 0:
        return np.nan

    return np.sum(np.abs(y_true - y_pred)) / denominator * 100


def fit_sarimax(y):
    model = SARIMAX(
        y,
        order=order,
        seasonal_order=seasonal_order,
        enforce_stationarity=False,
        enforce_invertibility=False
    )

    return model.fit(disp=False)


def period_end_date(period):
    return period.to_timestamp(how="end").normalize()


# =========================
# 5. Обучение и прогноз
# =========================

forecast_rows = []
metrics_rows = []

for product_name, product_df in df.groupby("product_name"):

    product_df = product_df.sort_values("period").copy()

    y_all = (
        product_df
        .set_index("period")[target_col]
        .astype(float)
        .sort_index()
    )

    # Для обучения не берем 2025 год
    y_train_raw = y_all[y_all.index <= train_end].dropna()

    if len(y_train_raw) < min_observations:
        print(f"Пропуск: {product_name} — мало наблюдений: {len(y_train_raw)}")
        continue

    first_train_period = y_train_raw.index.min()
    last_train_period = y_train_raw.index.max()

    # Для обычных товаров прогнозируем строго 2025Q1–2025Q4.
    # Для бензина/дизеля/газа прогнозируем от последнего заполненного квартала до 2025Q4.
    if product_name in partial_products:
        forecast_start = last_train_period + 1
    else:
        forecast_start = pd.Period("2025Q1", freq="Q")

    if forecast_start > forecast_end:
        continue

    forecast_periods = pd.period_range(
        forecast_start,
        forecast_end,
        freq="Q"
    )

    steps = len(forecast_periods)

    # Важно:
    # SARIMAX должен видеть квартальную сетку.
    # Если внутри ряда есть пропущенные кварталы, оставляем их как NaN.
    # Так модель не будет считать 2021Q4 и 2024Q1 соседними кварталами.
    full_train_periods = pd.period_range(
        first_train_period,
        last_train_period,
        freq="Q"
    )

    y_train = y_train_raw.reindex(full_train_periods)

    # =========================
    # Backtest
    # =========================

    bt_mae = np.nan
    bt_rmse = np.nan
    bt_mape = np.nan
    bt_wape = np.nan

    y_observed = y_train_raw.dropna()

    if len(y_observed) >= min_observations + 4:

        backtest_test_periods = y_observed.index[-4:]
        backtest_train_end = backtest_test_periods[0] - 1

        y_bt_train_raw = y_train_raw[y_train_raw.index <= backtest_train_end]
        y_bt_test = y_train_raw[y_train_raw.index.isin(backtest_test_periods)]

        if len(y_bt_train_raw.dropna()) >= min_observations and len(y_bt_test.dropna()) == 4:

            bt_full_periods = pd.period_range(
                y_bt_train_raw.index.min(),
                y_bt_train_raw.index.max(),
                freq="Q"
            )

            y_bt_train = y_bt_train_raw.reindex(bt_full_periods)

            try:
                fitted_bt = fit_sarimax(y_bt_train)

                bt_steps = len(
                    pd.period_range(
                        y_bt_train.index.max() + 1,
                        y_bt_test.index.max(),
                        freq="Q"
                    )
                )

                bt_pred_all = fitted_bt.forecast(steps=bt_steps)

                bt_forecast_periods = pd.period_range(
                    y_bt_train.index.max() + 1,
                    y_bt_test.index.max(),
                    freq="Q"
                )

                bt_pred = pd.Series(
                    np.asarray(bt_pred_all),
                    index=bt_forecast_periods
                ).reindex(y_bt_test.index)

                bt_mae = mean_absolute_error(y_bt_test.values, bt_pred.values)
                bt_rmse = rmse(y_bt_test.values, bt_pred.values)
                bt_mape = mape(y_bt_test.values, bt_pred.values)
                bt_wape = wape(y_bt_test.values, bt_pred.values)

            except Exception as e:
                print(f"Backtest ошибка: {product_name}: {e}")

    # =========================
    # Финальная модель
    # =========================

    try:
        fitted = fit_sarimax(y_train)

        forecast_result = fitted.get_forecast(steps=steps)

        forecast_mean = np.asarray(forecast_result.predicted_mean)
        forecast_ci = forecast_result.conf_int()
        forecast_ci = np.asarray(forecast_ci)

        for i, period in enumerate(forecast_periods):

            actual_value = (
                y_all.loc[period]
                if period in y_all.index and pd.notna(y_all.loc[period])
                else np.nan
            )

            forecast_rows.append({
                "product_name": product_name,
                "period": str(period),
                "period_end": period_end_date(period),
                "first_train_period": str(first_train_period),
                "last_train_period": str(last_train_period),
                "actual_target_demand_index": actual_value,
                "forecast_target_demand_index": forecast_mean[i],
                "forecast_lower": forecast_ci[i, 0],
                "forecast_upper": forecast_ci[i, 1],
                "is_2025_forecast": period.year == 2025,
                "model": "SARIMAX",
                "order": str(order),
                "seasonal_order": str(seasonal_order),
            })

        metrics_rows.append({
            "product_name": product_name,
            "observations_used": int(y_train_raw.notna().sum()),
            "first_train_period": str(first_train_period),
            "last_train_period": str(last_train_period),
            "forecast_start": str(forecast_start),
            "forecast_end": str(forecast_end),
            "backtest_mae": bt_mae,
            "backtest_rmse": bt_rmse,
            "backtest_mape": bt_mape,
            "backtest_wape": bt_wape,
        })

    except Exception as e:
        print(f"Ошибка модели: {product_name}: {e}")


forecast_df = pd.DataFrame(forecast_rows)
metrics_df = pd.DataFrame(metrics_rows)


# =========================
# 6. Метрики по 2025 году, если факт 2025 есть
# =========================

forecast_2025_with_fact = forecast_df[
    (forecast_df["is_2025_forecast"])
    & (forecast_df["actual_target_demand_index"].notna())
].copy()

metrics_2025 = []

for product_name, temp in forecast_2025_with_fact.groupby("product_name"):

    y_true = temp["actual_target_demand_index"].values
    y_pred = temp["forecast_target_demand_index"].values

    metrics_2025.append({
        "product_name": product_name,
        "test_period": "2025Q1-2025Q4",
        "test_mae_2025": mean_absolute_error(y_true, y_pred),
        "test_rmse_2025": rmse(y_true, y_pred),
        "test_mape_2025": mape(y_true, y_pred),
        "test_wape_2025": wape(y_true, y_pred),
    })

metrics_2025_df = pd.DataFrame(metrics_2025)

metrics_df = metrics_df.merge(
    metrics_2025_df,
    on="product_name",
    how="left"
)


# =========================
# 7. Сохранение
# =========================

forecast_df.to_csv(out_forecast, index=False, encoding="utf-8-sig")
metrics_df.to_csv(out_metrics, index=False, encoding="utf-8-sig")

print("Прогноз сохранен:", out_forecast)
print("Метрики сохранены:", out_metrics)

display(forecast_df.head(30))
display(metrics_df.sort_values("test_wape_2025", na_position="last"))
# Out:
# Прогноз сохранен: /home/senya/projects/diplom/dataset/sarimax_forecast_2025_fixed.csv
# Метрики сохранены: /home/senya/projects/diplom/dataset/sarimax_metrics_2025_fixed.csv
#                                          product_name  period period_end  \
# 0                                 Автомобили легковые  2025Q1 2025-03-31
# 1                                 Автомобили легковые  2025Q2 2025-06-30
# 2                                 Автомобили легковые  2025Q3 2025-09-30
# 3                                 Автомобили легковые  2025Q4 2025-12-31
# 4                               Бензины автомобильные  2024Q2 2024-06-30
# 5                               Бензины автомобильные  2024Q3 2024-09-30
# 6                               Бензины автомобильные  2024Q4 2024-12-31
# 7                               Бензины автомобильные  2025Q1 2025-03-31
# 8                               Бензины автомобильные  2025Q2 2025-06-30
# 9                               Бензины автомобильные  2025Q3 2025-09-30
# 10                              Бензины автомобильные  2025Q4 2025-12-31
# 11                           Газовое моторное топливо  2024Q2 2024-06-30
# 12                           Газовое моторное топливо  2024Q3 2024-09-30
# 13                           Газовое моторное топливо  2024Q4 2024-12-31
# 14                           Газовое моторное топливо  2025Q1 2025-03-31
# 15                           Газовое моторное топливо  2025Q2 2025-06-30
# 16                           Газовое моторное топливо  2025Q3 2025-09-30
# 17                           Газовое моторное топливо  2025Q4 2025-12-31
# 18                                  Дизельное топливо  2024Q2 2024-06-30
# 19                                  Дизельное топливо  2024Q3 2024-09-30
# 20                                  Дизельное топливо  2024Q4 2024-12-31
# 21                                  Дизельное топливо  2025Q1 2025-03-31
# 22                                  Дизельное топливо  2025Q2 2025-06-30
# 23                                  Дизельное топливо  2025Q3 2025-09-30
# 24                                  Дизельное топливо  2025Q4 2025-12-31
# 7       9.247979       9.311156      11.166912      11.030278  2025Q1-2025Q4
# 0      41.597500      49.462636      20.487723      21.796507  2025Q1-2025Q4
# 15     13.547245      15.832811      11.160131       9.878917  2025Q1-2025Q4
# 4       8.472747       8.833323       6.872198       6.895234  2025Q1-2025Q4
# 16     13.505211      14.180097       9.568887       8.946716  2025Q1-2025Q4
# 1   40500.009796   62064.954874   42514.442461   38731.052904            NaN
# 2      72.977415      77.161894      53.739045      54.186011            NaN
# 3       8.247466       9.782662       6.443509       5.893329            NaN
# 5       7.319867       8.035194      17.646726      15.555775            NaN
# 9      19.776619      22.675493      28.278939      29.255849            NaN
#
#     test_mae_2025  test_rmse_2025  test_mape_2025  test_wape_2025
# 12       2.838877        3.207804        2.748243        2.772215
# 6        4.185623        5.567492        3.788656        3.572936
# 11       4.231425        4.344535        3.559173        3.576019
# 10       4.443382        5.927461        3.996835        4.250633
# 18       9.454318       12.874012        6.254342        6.877972
# 8        9.437369       10.133575        6.957592        7.062500
# 13       9.964878       11.230284        7.390054        7.143627
# 17       7.177724        7.897193        7.762018        7.449600
# 14      10.657261       12.356110        9.138318        8.415442
# 7        9.761193       10.048001       12.198289       11.957993
# 0       21.260013       22.747118       14.183214       13.254391
# 15      23.886358       26.185393       14.646184       14.460716
# 4       27.252333       28.148339       28.343682       27.359441
# 16      36.040046       36.273005       29.055694       28.915276
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 5             NaN             NaN             NaN             NaN
# 9             NaN             NaN             NaN             NaN

# %%
forecast_df[
    ["product_name", "period", "last_train_period", "forecast_target_demand_index"]
].head(20)
# Out:
#                 product_name  period last_train_period  \
# 0        Автомобили легковые  2025Q1            2024Q4
# 1        Автомобили легковые  2025Q2            2024Q4
# 2        Автомобили легковые  2025Q3            2024Q4
# 3        Автомобили легковые  2025Q4            2024Q4
# 4      Бензины автомобильные  2024Q2            2024Q1
# 5      Бензины автомобильные  2024Q3            2024Q1
# 6      Бензины автомобильные  2024Q4            2024Q1
# 7      Бензины автомобильные  2025Q1            2024Q1
# 8      Бензины автомобильные  2025Q2            2024Q1
# 9      Бензины автомобильные  2025Q3            2024Q1
# 10     Бензины автомобильные  2025Q4            2024Q1
# 11  Газовое моторное топливо  2024Q2            2024Q1
# 12  Газовое моторное топливо  2024Q3            2024Q1
# 13  Газовое моторное топливо  2024Q4            2024Q1
# 14  Газовое моторное топливо  2025Q1            2024Q1
# 15  Газовое моторное топливо  2025Q2            2024Q1
# 16  Газовое моторное топливо  2025Q3            2024Q1
# 17  Газовое моторное топливо  2025Q4            2024Q1
# 18         Дизельное топливо  2024Q2            2024Q1
# 19         Дизельное топливо  2024Q3            2024Q1
#
#     forecast_target_demand_index
# 0                     167.330322
# 1                     166.881283
# 2                     166.871605
# 3                     168.435467
# 4                      91.878588
# 5                     110.471626
# 6                     102.028187
# 7                      88.456560
# 8                      89.873349
# 9                     107.601147
# 10                     99.559601
# 11                    150.185095
# 12                    181.269158
# 13                    203.178812
# 14                    144.129945
# 15                    154.824352
# 16                    186.862920
# 17                    208.672321
# 18                    122.777481
# 19                    171.909739

# %%
# ============================================================
# ЧБ-графики:
# прогноз расчетного спроса + индекс физического объема продаж
# Период: 2024–2025
# Ось X — месячная шкала
# ============================================================

from pathlib import Path
import re

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates


# ------------------------------------------------------------
# 1. Настройки
# ------------------------------------------------------------

SHOW_ALL_GRAPHS = False
SHOW_FIRST_N = 10

DATASET_DIR = Path.cwd() / "dataset"
CSV_DIR = DATASET_DIR / "csv"

PLOTS_DIR = DATASET_DIR / "plots_demand_vs_physical_volume"
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

FORECAST_START = pd.Timestamp("2025-01-01")

TARGET_COL = "target_demand_index"

PRODUCT_ID_COL = "product_code"
PRODUCT_NAME_COL = "product_name"

PHYSICAL_VOLUME_COL = "physical_volume_cumulative_yoy_index"



work = df.copy()

work["period_end"] = pd.to_datetime(work["period_end"])
work["period"] = work["period_end"].dt.to_period("Q").astype(str)

# На случай, если в df коды еще называются sales_product_code
if PRODUCT_ID_COL not in work.columns and "sales_product_code" in work.columns:
    work = work.rename(columns={"sales_product_code": PRODUCT_ID_COL})

if PRODUCT_NAME_COL not in work.columns and "sales_product_name" in work.columns:
    work = work.rename(columns={"sales_product_name": PRODUCT_NAME_COL})


if PHYSICAL_VOLUME_COL not in work.columns:

    physical_path = CSV_DIR / "physical_volume_product_quarterly.csv"

    physical = pd.read_csv(physical_path)

    physical["period_end"] = pd.to_datetime(physical["period_end"])
    physical["period"] = physical["period_end"].dt.to_period("Q").astype(str)

    # приводим названия колонок к единому виду
    rename_map = {}

    if "sales_product_code" in physical.columns:
        rename_map["sales_product_code"] = PRODUCT_ID_COL

    if "sales_product_name" in physical.columns:
        rename_map["sales_product_name"] = PRODUCT_NAME_COL

    # ищем колонку с индексом физического объема
    possible_physical_cols = [
        "physical_volume_index",
        "physical_volume_sales_index",
        "retail_physical_volume_index",
        "physical_volume",
        "index_physical_volume",
        "ifo_index",
    ]

    found_physical_col = None

    for col in possible_physical_cols:
        if col in physical.columns:
            found_physical_col = col
            break

    if found_physical_col is None:
        print("Колонки в physical_volume_product_quarterly.csv:")
        print(physical.columns.tolist())
        raise ValueError("Не нашел колонку с индексом физического объема продаж.")

    rename_map[found_physical_col] = PHYSICAL_VOLUME_COL

    physical = physical.rename(columns=rename_map)

    physical = physical[
        [
            PRODUCT_ID_COL,
            "period",
            PHYSICAL_VOLUME_COL,
        ]
    ].drop_duplicates()

    work = work.merge(
        physical,
        on=[PRODUCT_ID_COL, "period"],
        how="left"
    )


# ------------------------------------------------------------
# 4. Подготовка forecast_2025_df
# ------------------------------------------------------------

forecast_plot = forecast_df.copy()

# Унифицируем названия колонок прогноза
forecast_plot["period"] = forecast_plot["period"].astype(str)
forecast_plot["period_end"] = pd.to_datetime(forecast_plot["period_end"])

if "product_code" not in forecast_plot.columns:
    code_map = (
        work[[PRODUCT_ID_COL, PRODUCT_NAME_COL]]
        .drop_duplicates()
    )

    forecast_plot = forecast_plot.merge(
        code_map,
        on=PRODUCT_NAME_COL,
        how="left"
    )

if "forecast_target_demand_index" not in forecast_plot.columns:
    if "Прогноз спроса 2025" in forecast_plot.columns:
        forecast_plot = forecast_plot.rename(
            columns={"Прогноз спроса 2025": "forecast_target_demand_index"}
        )

if "actual_target_demand_index" not in forecast_plot.columns:
    if "Фактический спрос 2025" in forecast_plot.columns:
        forecast_plot = forecast_plot.rename(
            columns={"Фактический спрос 2025": "actual_target_demand_index"}
        )


# ------------------------------------------------------------
# 5. Список товаров для графиков
# ------------------------------------------------------------

if "metrics_df" in globals():
    plot_products = (
        metrics_df
        .sort_values(
            by=[col for col in ["test_wape_2025", "backtest_wape"] if col in metrics_df.columns],
            na_position="last"
        )["product_name"]
        .dropna()
        .unique()
        .tolist()
    )
else:
    plot_products = (
        forecast_plot[PRODUCT_NAME_COL]
        .dropna()
        .unique()
        .tolist()
    )

print("Товаров для построения графиков:", len(plot_products))


# ------------------------------------------------------------
# 6. Функция безопасного имени файла
# ------------------------------------------------------------

def make_safe_filename(value):
    value = str(value)
    value = re.sub(r"[^\wа-яА-ЯёЁ\-]+", "_", value)
    value = value.strip("_")
    return value[:120]


# ------------------------------------------------------------
# 7. Построение графиков
# ------------------------------------------------------------

for idx, product_name in enumerate(plot_products, start=1):

    hist = (
        work[work[PRODUCT_NAME_COL] == product_name]
        .sort_values("period_end")
        .copy()
    )

    fc = (
        forecast_plot[forecast_plot[PRODUCT_NAME_COL] == product_name]
        .sort_values("period_end")
        .copy()
    )

    if hist.empty or fc.empty:
        continue

    product_id = hist[PRODUCT_ID_COL].iloc[0]

    group_name = ""
    for group_col in ["group_name", "product_group_name"]:
        if group_col in hist.columns:
            group_name = hist[group_col].dropna().iloc[0] if hist[group_col].notna().any() else ""
            break

    # Факт 2024–2025
    hist_plot = hist[
        (hist["period_end"] >= pd.Timestamp("2024-01-01")) &
        (hist["period_end"] <= pd.Timestamp("2025-12-31"))
    ].copy()

    # Прогноз 2025 или прогноз от последнего заполненного квартала
    fc_plot = fc[
        (fc["period_end"] >= pd.Timestamp("2024-01-01")) &
        (fc["period_end"] <= pd.Timestamp("2025-12-31"))
    ].copy()

    if hist_plot.empty and fc_plot.empty:
        continue

    fig, ax = plt.subplots(figsize=(10.5, 5.2))

    # --------------------------------------------------------
    # Фактический расчетный спрос
    # --------------------------------------------------------

    hist_fact = hist_plot[hist_plot[TARGET_COL].notna()].copy()

    ax.plot(
        hist_fact["period_end"],
        hist_fact[TARGET_COL],
        color="black",
        linestyle="-",
        linewidth=2.2,
        marker="o",
        markersize=5,
        label="Фактический индекс спроса"
    )

    # --------------------------------------------------------
    # Прогноз спроса
    # --------------------------------------------------------

    ax.plot(
        fc_plot["period_end"],
        fc_plot["forecast_target_demand_index"],
        color="black",
        linestyle="--",
        linewidth=2.4,
        marker="s",
        markersize=5,
        label="Прогноз спроса"
    )

    # --------------------------------------------------------
    # Фактический спрос 2025, если он есть
    # --------------------------------------------------------

    if "actual_target_demand_index" in fc_plot.columns:
        actual_2025 = fc_plot[
            fc_plot["actual_target_demand_index"].notna()
        ].copy()

        if not actual_2025.empty:
            ax.plot(
                actual_2025["period_end"],
                actual_2025["actual_target_demand_index"],
                color="black",
                linestyle="-.",
                linewidth=2.0,
                marker="D",
                markersize=5,
                label="Фактический спрос 2025"
            )

    # --------------------------------------------------------
    # Индекс физического объема продаж
    # --------------------------------------------------------

    if PHYSICAL_VOLUME_COL in hist_plot.columns:
        physical_plot = hist_plot[
            hist_plot[PHYSICAL_VOLUME_COL].notna()
        ].copy()

        if not physical_plot.empty:
            ax.plot(
                physical_plot["period_end"],
                physical_plot[PHYSICAL_VOLUME_COL],
                color="dimgray",
                linestyle=":",
                linewidth=2.4,
                marker="^",
                markersize=5,
                label="Индекс физического объема продаж"
            )

    # --------------------------------------------------------
    # Начало прогноза
    # --------------------------------------------------------

    ax.axvline(
        FORECAST_START,
        color="black",
        linestyle=":",
        linewidth=1.4,
        label="Начало прогноза"
    )

    # --------------------------------------------------------
    # Оформление
    # --------------------------------------------------------

    title = f"SARIMAX: прогноз спроса и индекс физического объема продаж\n{product_name}"

    if group_name:
        title += f"\n{group_name}"

    ax.set_title(
        title,
        fontsize=13,
        fontweight="bold"
    )

    ax.set_xlabel("Месяц", fontsize=11, fontweight="bold")
    ax.set_ylabel("Индекс", fontsize=11, fontweight="bold")

    ax.set_xlim(
        pd.Timestamp("2024-01-01"),
        pd.Timestamp("2025-12-31")
    )

    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

    plt.setp(
        ax.get_xticklabels(),
        rotation=45,
        ha="right",
        fontsize=8.5
    )

    ax.grid(
        True,
        axis="y",
        linestyle=":",
        linewidth=0.8,
        alpha=0.7
    )

    for spine in ax.spines.values():
        spine.set_linewidth(1.0)
        spine.set_color("black")

    ax.legend(
        fontsize=8.8,
        frameon=True,
        edgecolor="black",
        loc="best"
    )

    plt.tight_layout()

    safe_id = make_safe_filename(product_id)
    out_path = PLOTS_DIR / f"sarimax_demand_forecast_vs_physical_volume_2024_2025_{safe_id}.png"

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight",
        facecolor="white"
    )

    if SHOW_ALL_GRAPHS or idx <= SHOW_FIRST_N:
        plt.show()
    else:
        plt.close(fig)

print("Графики сохранены в папку:", PLOTS_DIR)
# Out:
# Колонки в physical_volume_product_quarterly.csv:
# ['region', 'sales_product_name', 'period_end', 'physical_volume_cumulative_yoy_index', 'year_header', 'quarter_header', 'period_label', 'is_full_year_column', 'year', 'quarter', 'region_scope', 'product_group_code', 'product_group_name', 'source_file', 'period']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 91
#      87
#      88     if found_physical_col is None:
#      89         print("Колонки в physical_volume_product_quarterly.csv:")
#      90         print(physical.columns.tolist())
# ---> 91         raise ValueError("Не нашел колонку с индексом физического объема продаж.")
#      92
#      93     rename_map[found_physical_col] = PHYSICAL_VOLUME_COL
#      94
#
# ValueError: Не нашел колонку с индексом физического объема продаж.
