# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============================================================
# BLOCK: external Rosstat / Fedstat features for demand model
# Place this block after quarterly_data is created,
# but before candidate_features and model training.
# ============================================================

# !pip -q install xlrd

import re
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

BASE_DIR = Path("/content/drive/MyDrive/rostat")

EXTERNAL_DIRS = [
    BASE_DIR,
    BASE_DIR / "external",
    BASE_DIR / "external_rosstat",
    Path("/content"),
]

OUTPUT_DIR = BASE_DIR / "quarterly_model_selection_staged"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MONTH_MAP = {
    "январь": 1,
    "февраль": 2,
    "март": 3,
    "апрель": 4,
    "май": 5,
    "июнь": 6,
    "июль": 7,
    "август": 8,
    "сентябрь": 9,
    "октябрь": 10,
    "ноябрь": 11,
    "декабрь": 12,
}

QUARTER_PERIOD_MAP = {
    "январь-март": 1,
    "январь-июнь": 2,
    "январь-сентябрь": 3,
    "январь-декабрь": 4,
    "значение показателя за год": 4,
}

GROUP_NAME_BY_CODE = (
    quarterly_data[["product_group_code", "product_group_name"]]
    .drop_duplicates()
    .set_index("product_group_code")["product_group_name"]
    .to_dict()
)

print("Группы в текущем датасете:")
display(pd.DataFrame(GROUP_NAME_BY_CODE.items(), columns=["product_group_code", "product_group_name"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58616/2721792685.py in <cell line: 0>()
#      53
#      54 GROUP_NAME_BY_CODE = (
# ---> 55     quarterly_data[["product_group_code", "product_group_name"]]
#      56     .drop_duplicates()
#      57     .set_index("product_group_code")["product_group_name"]
#
# NameError: name 'quarterly_data' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from google.colab import drive
drive.mount("/content/gdrive")



BASE_DIR = Path("/content/gdrive/MyDrive/rostat")

possible_paths = [
    BASE_DIR / "csv" / "group_quarterly_dataset.csv",
]

DATA_PATH = None
for path in possible_paths:
    if path.exists():
        DATA_PATH = path
        break

if DATA_PATH is None:
    matches = list(BASE_DIR.rglob("group_quarterly_dataset.csv"))
    if len(matches) > 0:
        DATA_PATH = matches[0]

if DATA_PATH is None:
    raise FileNotFoundError(
        "Не найден файл group_quarterly_dataset.csv внутри /content/gdrive/MyDrive/rostat"
    )

OUT_DIR = BASE_DIR / "figures_for_diploma"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print("Используется файл:", DATA_PATH)
print("Папка для рисунков:", OUT_DIR)

# ------------------------------------------------------------
# 2. Загрузка квартального набора данных
# ------------------------------------------------------------

df = pd.read_csv(DATA_PATH, parse_dates=["period_end"])
df["period_end"] = pd.to_datetime(df["period_end"])
df = df.sort_values(["product_group_code", "period_end"]).reset_index(drop=True)

print("Размер набора данных:", df.shape)
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_70315/3827129214.py in <cell line: 0>()
#       5
#       6 from google.colab import drive
# ----> 7 drive.mount("/content/gdrive")
#       8
#       9
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# ...
